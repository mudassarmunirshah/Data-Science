# %% [markdown]
# _**Operators**_

# %%
print(3+3) #addition
print(6-3) #subtraction
print(3*3) #multiplication
print(9/3) #division
print(10%3) #modulus

print(2/3) # you will get answer as a float number
print(2//3) # you will get answer as a integer number
print(2**3) # power or exponent
print(2%3) #Remainder or modulus

#Python always use "PEMDAS" rule for mathematical operations
#PEMDAS (Parenthesis, Exponents, Multiplication, Division, Addition, Subtraction)
print(2**4/2+5*21-44/36*44/(2**7))
#Read about PEMDAS
# Out:
# 6
# 3
# 9
# 3.0
# 1
# 0.6666666666666666
# 0
# 8
# 2

# %% [markdown]
# _**Strings**_

# %%
#print('Mudass') #single quotes
#print("Mudass") #double quotes
print(''' Mudassar
      Civil Engineer
      Pakistan''') #triple quotes for multi line strings
# Out:
#  Mudassar
#       Civil Engineer
#       Pakistan

# %% [markdown]
# _**Commen_ts**

# %%
print(3+5) #addition
#print(10-2) #subtraction
print(4*2) #multiplication
print(16/2) #division
# Out:
# 8
# 8
# 8.0

# %% [markdown]
# _**Variables**_

# %%
#Practice of veriables: objects containing specific values
a = 10
b = 5
c = a + b
print(c)
name = "Mudassar" #string variable
age = 27 #integer variable
height = 5.9 #float variable
is_student = True #boolean variable
#Rules for variables
#Rules of veriables
#R-1: Verables must contain number, letter, or underscore
a=4
#R-2: Verables do not start with number (5=x or 2=y)
5=x
2=y
#R-3: Verables are case sensitive (x and X are different) recommended is lower case
x=10
X=15
#R-4: Verables can be a combination of letters and numbers (x1, x2, etc.)
x1=10
x2=23
#R-5: spaces are not allowed (fruit_basket)
student_name= "mudassar"
#R-6: Short and discriptive

#R-7: Do not use keywords or function nemes of python as veriable name (mean, mode, media, test)
#R-8: Do not use special characters (, !, @, #, $,)
#R-9: Do not use special symbols (., /, \, etc.)
# Out:
# 15

# %% [markdown]
# **Logical variables**

# %%
#true or false, 0 and 1, yes and no
#equal to==
print(5==5) #true
print(5==3) #false
#not eaual to !=
print(5!=3) #true
print(8<7) #false
print(7>3) #true
#greater then or equal to                   >=
#less than or equal to                      <=
print(5>=5) #true
print(4<=3) #false
# Out:
# True
# False
# True
# False
# True
# True
# False

# %% [markdown]
# _**Functions**_

# %%
#define a function
#1 method
def print_name(): #function name
    print('mudassar') #function body
    print('Civil Engineer')
    print('Pak')
print_name() #function call
#2 method
def print_name():
    text='Mudassar'
    print(text)
    print(text)
    print(text)
print_name()
# Out:
# mudassar
# Civil Engineer
# Pak
# Mudassar
# Mudassar
# Mudassar

# %% [markdown]
# _**How to import Libraries**_

# %%
import math
print(math.pi) #print value of pi
# Out:
# 3.141592653589793

# %%
# Out:
# 1.6197751905438615

# %%
x=[234,6788,5678,768,678,4567,4567,45678,3456]
import statistics
print(statistics.mean(x)) #minimum value in the list
# Out:
# 8046

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\mudassar\appdata\local\programs\python\python314\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mudassar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\mudassar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mudassar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mudassar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\mudassar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mudassar\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\mudassar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\mudassar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mudassar\appdata\roaming\python\python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\mudassar\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()
