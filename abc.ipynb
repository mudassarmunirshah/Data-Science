# %% [markdown]
# _**Operators**_

# %%
print(2+3) #addition
print(5-2) #subtraction
print(4*3) #multiplication
# Out:
# 5
# 3
# 12

# %%
print(2/3) # you will get answer as a float number
print(2//3) # you will get answer as a integer number
print(2**3) # power or exponent
print(2%3) #Remainder or modulus
#Python always use "PEMDAS" rule for mathematical operations
#PEMDAS (Parenthesis, Exponents, Multiplication, Division, Addition, Subtraction)
print((2+3)*4**2)
# Out:
# 0.6666666666666666
# 0
# 8
# 2
# 80

# %% [markdown]
# **Strings**:

# %%
print('mudassar shah') #single quotes
print("mudassar shah") #double quotes
print('''Mudassar
      Civil Engineer
      From Pakistan''') #triple quotes for multiple lines)
# Out:
# mudassar shah
# mudassar shah
# Mudassar
#       Civil Engineer
#       From Pakistan

# %% [markdown]
# **Comments:**

# %%
#print('mudassar shah') #single quotes
#print("mudassar shah") #double quotes
print('''Mudassar
      Civil Engineer
      From Pakistan''') #triple quotes for multiple lines)
# Out:
# Mudassar
#       Civil Engineer
#       From Pakistan

# %% [markdown]
# _**Variables:**_

# %%
x=2
y=4
print(x+y) 
b= "mudassar"
print(b)

z=7.0
print(z)
print(type(z))
#Rules of veriable 
#Rules of veriables
#R-1: Verables must contain number, letter, or underscore
#R-2: Verables do not start with number (5=x or 2=y)
#R-3: Verables are case sensitive (x and X are different) recommended is lower case
x=100
print(x)
#R-4: Verables can be a combination of letters and numbers (x1, x2, etc.)\
x1=50
x2=60
print(x1+x2)
#R-5: spaces are not allowed (fruit_basket)
student_name= "mudassar"

#R-6: Short and discriptive
#R-7: Do not use keywords or function nemes of python as veriable name (mean, mode, media, test)
#R-8: Do not use special characters (, !, @, #, $,)
# Out:
# 6
# mudassar
# 7.0
# <class 'float'>
# 100
# 110

# %% [markdown]
# _**Logical variables**_

# %%
#equal to                                   ==
#not equal to                               !=
#greater than                               >
#less than                                  <
#greater then or equal to                   >=
#less than or equal to                      <=
print(2!=2) #False
print(2>=4)
# Out:
# False
# False

# %% [markdown]
# **Functions:**

# %%
def print_name(): #function definition
    print("Mudassar Shah") #function body
    #print("Mudassar Shah")
    print("Mudassar Shah")
print_name() #function call

#method 2
def print_name():
    text="Faraz"
    print(text)
    print(text)

print_name()
# Out:
# Mudassar Shah
# Mudassar Shah
# Faraz
# Faraz

# %% [markdown]
# **How to import Libraries**

# %%
import math
print(math.pi)
print(math.sqrt(16))
import statistics
x=[3456,4567,4567,45678,5677]
print(statistics.mode(x))
# Out:
# 3.141592653589793
# 4.0
# 4567

# %% [markdown]
# List of importent labraries for Data Sci
# 1. pandas : data manipulation and analysis {same as excel}
# 2. numpy : to understand the data type
# 3. matplotlib : to visualize the data {world famious for plot creation}
# 4. seaborn : based on matplotlib with extra features
# 5. plotly : interactive plots {kamal library hai}
# 6. scipy: for statistical analysis
# 7. scikit-learn: for machine learning
# 8. streamlit : to create web app of data sci {fast and easy to use}

# %%
pip install pandas
# Out:
#   Cell In[39], line 2
#     pip install numpy
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %% [markdown]
#  How can you get a code of any plot from gallery of any library for example seaborn library gallery\
#  [seaborn gallery](https://seaborn.pydata.org/examples/radial_facets.html)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = (
    flights_long
    .pivot(index="month", columns="year", values="passengers")
)

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
import plotly.express as px

fig = px.imshow([[1, 20, 30],
                 [20, 1, 60],
                 [30, 60, 1]])
fig.show()
